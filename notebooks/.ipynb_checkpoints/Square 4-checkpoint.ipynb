# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.model_selection import train_test_split


import warnings
warnings.simplefilter('ignore')

# %%
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from scipy.stats import uniform

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import SGDClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix

from sklearn.metrics import log_loss
from sklearn.calibration import CalibratedClassifierCV

from sklearn.feature_selection import RFECV

# %%
import xgboost
from xgboost import plot_importance
from xgboost import plot_tree
from xgboost import XGBClassifier

# %%
tourney_result = pd.read_csv('../input/kaggle_data/MNCAATourneyCompactResults.csv')

tourney_result = tourney_result.drop(['DayNum', 'WScore', 'LScore', 'WLoc', 'NumOT'],axis=1)

# %%
coty = pd.read_csv('../input/coty.csv')
coty
# Out:
#        Season  TeamID  coty
# 0        1985    1102     0
# 1        1985    1103     0
# 2        1985    1104     0
# 3        1985    1106     0
# 4        1985    1108     0
# 5        1985    1109     0
# 6        1985    1110     0
# 7        1985    1111     0
# 8        1985    1112     0
# 9        1985    1113     0
# 10       1985    1114     0
# 11       1985    1116     1
# 12       1985    1117     0
# 13       1985    1119     0
# 14       1985    1120     0
# 15       1985    1121     0
# 16       1985    1122     0
# 17       1985    1123     0
# 18       1985    1124     0
# 19       1985    1126     0
# 20       1985    1129     0
# 21       1985    1130     0
# 22       1985    1131     0
# 23       1985    1132     0
# 24       1985    1133     0
# 25       1985    1134     0
# 26       1985    1135     0
# 27       1985    1137     0
# 28       1985    1139     0
# 29       1985    1140     0
# ...       ...     ...   ...
# 11318    2019    1435     0
# 11319    2019    1436     0
# 11320    2019    1437     0
# 11321    2019    1438     1
# 11322    2019    1439     0
# 11323    2019    1440     0
# 11324    2019    1441     0
# 11325    2019    1442     0
# 11326    2019    1443     0
# 11327    2019    1444     0
# 11328    2019    1447     0
# 11329    2019    1448     0
# 11330    2019    1449     0
# 11331    2019    1450     0
# 11332    2019    1451     0
# 11333    2019    1452     0
# 11334    2019    1453     0
# 11335    2019    1454     0
# 11336    2019    1455     1
# 11337    2019    1456     0
# 11338    2019    1457     0
# 11339    2019    1458     0
# 11340    2019    1459     0
# 11341    2019    1460     0
# 11342    2019    1461     0
# 11343    2019    1462     0
# 11344    2019    1463     0
# 11345    2019    1464     0
# 11346    2019    1465     0
# 11347    2019    1466     0
#
# [11348 rows x 3 columns]

# %%
adj_eff = pd.read_csv('../input/self_calculated/adjusted_efficiencies.csv')
consistency = pd.read_csv('../input/self_calculated/consistency.csv')

consistency
# Out:
#       Season  TeamID   Pos_std  tm_off_eff_std  tm_def_eff_std
# 0       2003    1102  4.544885       23.752202       21.316022
# 1       2003    1103  8.768290       14.223345       12.598310
# 2       2003    1104  4.578047       14.554749       15.141803
# 3       2003    1105  5.924156       16.307845       19.190037
# 4       2003    1106  4.980870       14.784855       18.732358
# 5       2003    1107  5.930437       13.248183       16.426759
# 6       2003    1108  5.327232       12.204852       13.567259
# 7       2003    1110  4.529160       14.825526       13.739147
# 8       2003    1111  8.645432       14.179801       17.582319
# 9       2003    1112  5.680541       13.211491       13.021743
# 10      2003    1113  4.578849       16.289954       17.096088
# 11      2003    1114  7.001191       16.899578       16.550049
# 12      2003    1115  4.314611       17.578782       19.203836
# 13      2003    1116  6.160655       15.352074       17.657553
# 14      2003    1117  5.099994       16.308233       17.138450
# 15      2003    1119  6.020396       14.199842       11.146321
# 16      2003    1120  4.384484       18.966531       20.422805
# 17      2003    1122  5.434618       17.095357       13.045569
# 18      2003    1123  5.630520       16.647440       15.157230
# 19      2003    1124  4.840672       14.385595       18.164913
# 20      2003    1125  6.713437       16.468303       16.471749
# 21      2003    1126  7.503785       15.013337       18.327888
# 22      2003    1127  4.563621       15.411990       16.055986
# 23      2003    1128  5.054951       16.436966       14.721724
# 24      2003    1129  5.325279       10.478523       11.266163
# 25      2003    1130  7.237526       16.033782       13.656905
# 26      2003    1131  4.860374       13.371976       12.769338
# 27      2003    1132  4.934101       12.229262       13.039712
# 28      2003    1133  7.032037       16.634482       16.123492
# 29      2003    1135  5.072054       18.362838       12.722505
# ...      ...     ...       ...             ...             ...
# 6157    2020    1436  4.301810       15.933352       16.518419
# 6158    2020    1437  4.052164       15.346884       15.668465
# 6159    2020    1438  3.572559       14.146245       20.170867
# 6160    2020    1439  6.189232       17.396476       19.843223
# 6161    2020    1440  4.713392       14.303501       10.363250
# 6162    2020    1441  5.294727       12.878482       12.994112
# 6163    2020    1442  3.986195       15.544316       16.634287
# 6164    2020    1443  5.401727       14.555821       11.547320
# 6165    2020    1444  7.915223       12.186121       12.508958
# 6166    2020    1447  6.200685       12.782637       15.608942
# 6167    2020    1448  5.353220       14.257492       15.384531
# 6168    2020    1449  5.226430       13.798361       14.471334
# 6169    2020    1450  5.194722       13.765396       14.377452
# 6170    2020    1451  5.481274       16.491295       13.191110
# 6171    2020    1452  4.894693       15.252483       15.578333
# 6172    2020    1453  4.535783       14.826161       12.804508
# 6173    2020    1454  8.236443       10.550942       13.870716
# 6174    2020    1455  6.528090       15.331430       12.888206
# 6175    2020    1456  4.451385       14.732467       15.612050
# 6176    2020    1457  6.231122       15.903956       12.873500
# 6177    2020    1458  3.614152       15.933862       14.501490
# 6178    2020    1459  5.543924       14.535549       18.109702
# 6179    2020    1460  4.013186       14.894132       12.450876
# 6180    2020    1461  5.933148       14.508032       16.280030
# 6181    2020    1462  4.721593        9.577543       14.366395
# 6182    2020    1463  5.810585       14.717902       12.918229
# 6183    2020    1464  5.049509       13.920679       15.443705
# 6184    2020    1465  6.316359       19.379314       17.524242
# 6185    2020    1466  4.287972       12.517820       18.282702
# 6186    2020    1467  4.255399       12.985489       15.050716
#
# [6187 rows x 5 columns]

# %%
all_teams = adj_eff.merge(coty,on=['Season','TeamID'])
all_teams = all_teams.merge(consistency,on=['Season','TeamID'])

all_teams = all_teams[['Season','TeamID','AdjNetEff','coty','tm_off_eff_std','tm_def_eff_std']]
all_teams.columns = ['Season','TeamID','AdjNetEff','coty','off_cons','def_cons']

all_teams
# Out:
#       Season  TeamID  AdjNetEff  coty   off_cons   def_cons
# 0       2003    1102   2.549120     0  23.752202  21.316022
# 1       2003    1103  -0.892082     0  14.223345  12.598310
# 2       2003    1104  16.005042     0  14.554749  15.141803
# 3       2003    1105 -17.739565     0  16.307845  19.190037
# 4       2003    1106  -9.118578     0  14.784855  18.732358
# 5       2003    1107 -18.899802     0  13.248183  16.426759
# 6       2003    1108 -11.597642     0  12.204852  13.567259
# 7       2003    1110   2.761780     0  14.825526  13.739147
# 8       2003    1111  -0.574032     0  14.179801  17.582319
# 9       2003    1112  27.877550     0  13.211491  13.021743
# 10      2003    1113  18.390055     0  16.289954  17.096088
# 11      2003    1114  -0.015182     0  16.899578  16.550049
# 12      2003    1115 -28.874116     0  17.578782  19.203836
# 13      2003    1116   3.017128     0  15.352074  17.657553
# 14      2003    1117   0.920368     0  16.308233  17.138450
# 15      2003    1119 -26.155624     0  14.199842  11.146321
# 16      2003    1120  13.933611     1  18.966531  20.422805
# 17      2003    1122   2.853880     0  17.095357  13.045569
# 18      2003    1123  -0.855332     0  16.647440  15.157230
# 19      2003    1124   5.664838     0  14.385595  18.164913
# 20      2003    1125   0.559161     0  16.468303  16.471749
# 21      2003    1126 -22.435246     0  15.013337  18.327888
# 22      2003    1127  -3.039834     0  15.411990  16.055986
# 23      2003    1128  -6.764140     0  16.436966  14.721724
# 24      2003    1129  -2.310176     0  10.478523  11.266163
# 25      2003    1130  12.945751     0  16.033782  13.656905
# 26      2003    1131   4.656605     0  13.371976  12.769338
# 27      2003    1132  -2.114048     0  12.229262  13.039712
# 28      2003    1133   1.992168     0  16.634482  16.123492
# 29      2003    1135   0.927669     0  18.362838  12.722505
# ...      ...     ...        ...   ...        ...        ...
# 5858    2019    1435   1.123002     0  17.788550  14.398645
# 5859    2019    1436  10.230112     0  14.570757  16.014680
# 5860    2019    1437  19.470659     0  15.355736  14.555695
# 5861    2019    1438  38.342042     1  15.401973  17.231829
# 5862    2019    1439  27.322988     0  16.794142  22.405941
# 5863    2019    1440 -12.061122     0  16.609458  15.362324
# 5864    2019    1441 -10.716380     0  18.402254  13.940453
# 5865    2019    1442 -11.781162     0  15.462345  17.790166
# 5866    2019    1443   5.248860     0  12.990762  11.230808
# 5867    2019    1444  -7.891405     0  15.380055  12.857568
# 5868    2019    1447 -14.795961     0  17.180423  14.479280
# 5869    2019    1448  -0.737209     0  15.529671  15.317176
# 5870    2019    1449  14.602751     0  13.235149  15.467104
# 5871    2019    1450  -4.879765     0  14.702409  17.757550
# 5872    2019    1451  -4.708466     0  15.882582  13.794295
# 5873    2019    1452   6.859123     0  18.084224  14.361113
# 5874    2019    1453  -3.476639     0  14.698219  14.792078
# 5875    2019    1454 -11.564373     0  13.407588  12.346530
# 5876    2019    1455   7.394695     1  17.172844  14.690725
# 5877    2019    1456  -5.461721     0  14.141136  14.340569
# 5878    2019    1457  -0.830764     0  15.604370  14.663260
# 5879    2019    1458  24.879447     0  15.708520  12.612383
# 5880    2019    1459  21.792046     0  17.053913  16.477822
# 5881    2019    1460   4.861012     0  15.787097  12.649954
# 5882    2019    1461 -14.647438     0  16.202043  11.561724
# 5883    2019    1462  10.334408     0  15.308014  13.884688
# 5884    2019    1463   9.400521     0  18.070206  15.378596
# 5885    2019    1464  -9.679544     0  13.546129  14.753717
# 5886    2019    1465  -2.341565     0  16.297274  14.564338
# 5887    2019    1466 -11.507505     0  12.647478  15.959722
#
# [5888 rows x 6 columns]

# %%
df1 = tourney_result
df2 = all_teams

df = df1.merge(df2,left_on=['Season','WTeamID'],right_on=['Season','TeamID'], how="inner")

df = df.drop(['TeamID'],axis=1)

df = df.merge(df2,left_on=['Season','LTeamID'],right_on=['Season','TeamID'],how='inner')
df = df.drop(['TeamID'],axis=1)

print(df.columns)
# Out:
# Index(['Season', 'WTeamID', 'LTeamID', 'AdjNetEff_x', 'coty_x', 'off_cons_x',
#        'def_cons_x', 'AdjNetEff_y', 'coty_y', 'off_cons_y', 'def_cons_y'],
#       dtype='object')

# %%
df_win = df.copy()

df_lose = df_win.copy()

df_lose['AdjNetEff_x'] = df_win['AdjNetEff_y']
df_lose['AdjNetEff_y'] = df_win['AdjNetEff_x']

df_lose['coty_x'] = df_win['coty_y']
df_lose['coty_y'] = df_win['coty_x']

df_lose['off_cons_x'] = df_win['off_cons_y']
df_lose['off_cons_y'] = df_win['off_cons_x']

df_lose['def_cons_x'] = df_win['def_cons_y']
df_lose['def_cons_y'] = df_win['def_cons_x']


df_lose
# Out:
#       Season  WTeamID  LTeamID  AdjNetEff_x  coty_x  off_cons_x  def_cons_x  \
# 0       2003     1421     1411    -8.798933       0   14.155399   18.094586
# 1       2003     1112     1436     2.581903       0   17.182535   13.232777
# 2       2003     1112     1211    16.074004       0   13.140022   16.089789
# 3       2003     1112     1323    21.393782       0   13.962640   19.286616
# 4       2003     1113     1272    17.376061       0    9.061950   14.344667
# 5       2003     1141     1166    21.599672       0   14.467639   15.065417
# 6       2003     1143     1301    13.249313       0   15.369050   15.957973
# 7       2003     1163     1140    19.820683       0   14.503437   15.874542
# 8       2003     1163     1390    15.205756       0   11.922719   12.970978
# 9       2003     1181     1161     5.709327       0   13.839161   15.873602
# 10      2003     1181     1141    10.344505       0   16.061633   12.116463
# 11      2003     1211     1153    16.149309       0   14.715984   16.387538
# 12      2003     1228     1443    11.708819       0   12.571454   17.449202
# 13      2003     1242     1429     7.607993       0   14.108326   11.457323
# 14      2003     1242     1113    18.390055       0   16.289954   17.096088
# 15      2003     1242     1181    23.058384       0   11.334966   16.073131
# 16      2003     1242     1112    27.877550       0   13.211491   13.021743
# 17      2003     1242     1266    22.139592       0   12.547894   11.749139
# 18      2003     1266     1221    12.478253       0   14.914222   17.632414
# 19      2003     1266     1281    18.672070       0   13.911666   15.913744
# 20      2003     1266     1338    28.131535       1   11.733838   13.815227
# 21      2003     1266     1246    29.841834       0   12.838221   13.238098
# 22      2003     1281     1356    12.176532       0   13.108164   11.619150
# 23      2003     1323     1454    13.022805       0   11.896788   16.996648
# 24      2003     1323     1228    26.694111       0   14.595200   15.069917
# 25      2003     1328     1354    -8.246421       0   14.762176   13.299781
# 26      2003     1328     1143    13.464684       0   10.462607   15.701468
# 27      2003     1328     1139    16.342782       0   13.349464   16.105076
# 28      2003     1390     1360     7.806387       0   13.542722   14.666794
# 29      2003     1409     1173    15.745053       0   10.359828   14.674485
# ...      ...      ...      ...          ...     ...         ...         ...
# 1092    2019     1181     1416    16.025271       0   13.175579   14.491812
# 1093    2019     1181     1439    27.322988       0   16.794142   22.405941
# 1094    2019     1222     1209     5.369233       0   12.999371   13.594726
# 1095    2019     1222     1326    16.532358       0   16.728539   14.908311
# 1096    2019     1234     1153    18.998412       0   13.649702   13.133721
# 1097    2019     1251     1280    21.167872       1   13.961506   13.843805
# 1098    2019     1314     1233    -3.766572       0   14.418741   13.388852
# 1099    2019     1314     1449    14.602751       0   13.235149   15.467104
# 1100    2019     1326     1235    23.333404       0   13.938638   16.519329
# 1101    2019     1328     1279    15.941188       0   12.143397   14.024066
# 1102    2019     1332     1458    24.879447       0   15.708520   12.612383
# 1103    2019     1332     1414    10.490904       0   18.166852   15.787677
# 1104    2019     1397     1159     4.359404       0   13.857461   14.295712
# 1105    2019     1397     1234    16.747649       0   16.741771   14.997189
# 1106    2019     1403     1297     7.266444       0   15.524882   14.482681
# 1107    2019     1403     1138    22.402995       0   11.186274   14.242635
# 1108    2019     1403     1276    30.123887       0   13.389575   16.026487
# 1109    2019     1403     1211    38.380319       1   15.502224   20.054956
# 1110    2019     1403     1277    33.625251       1   13.238895   14.725790
# 1111    2019     1414     1243    20.397884       1   16.341310   14.936992
# 1112    2019     1416     1433    17.123388       0   13.631023   14.105654
# 1113    2019     1438     1205    -0.761242       0   15.364894   16.467241
# 1114    2019     1438     1328    16.739650       0   12.162862   14.931043
# 1115    2019     1438     1332    16.965747       0   16.481907   16.651683
# 1116    2019     1438     1345    28.013135       0   16.543824   16.086429
# 1117    2019     1438     1120    25.515032       0   14.012993   18.323993
# 1118    2019     1438     1403    28.677540       0   19.308752   15.534991
# 1119    2019     1439     1387     6.539615       0   11.149533   15.103102
# 1120    2019     1439     1251    10.968803       0   11.555881   14.918311
# 1121    2019     1449     1429    17.956987       0   16.604302   15.373199
#
#       AdjNetEff_y  coty_y  off_cons_y  def_cons_y
# 0      -15.290412       0   16.642408   14.289006
# 1       27.877550       0   13.211491   13.021743
# 2       27.877550       0   13.211491   13.021743
# 3       27.877550       0   13.211491   13.021743
# 4       18.390055       0   16.289954   17.096088
# 5       10.344505       0   16.061633   12.116463
# 6       13.464684       0   10.462607   15.701468
# 7       18.387632       1   15.141179   12.875165
# 8       18.387632       1   15.141179   12.875165
# 9       23.058384       0   11.334966   16.073131
# 10      23.058384       0   11.334966   16.073131
# 11      16.074004       0   13.140022   16.089789
# 12      26.694111       0   14.595200   15.069917
# 13      30.564914       1   15.559062   15.839781
# 14      30.564914       1   15.559062   15.839781
# 15      30.564914       1   15.559062   15.839781
# 16      30.564914       1   15.559062   15.839781
# 17      30.564914       1   15.559062   15.839781
# 18      22.139592       0   12.547894   11.749139
# 19      22.139592       0   12.547894   11.749139
# 20      22.139592       0   12.547894   11.749139
# 21      22.139592       0   12.547894   11.749139
# 22      18.672070       0   13.911666   15.913744
# 23      21.393782       0   13.962640   19.286616
# 24      21.393782       0   13.962640   19.286616
# 25      25.453028       1   16.914175   13.776264
# 26      25.453028       1   16.914175   13.776264
# 27      25.453028       1   16.914175   13.776264
# 28      15.205756       0   11.922719   12.970978
# 29      12.343923       0   10.136824   14.423715
# ...           ...     ...         ...         ...
# 1092    35.916612       0   14.954422   16.842087
# 1093    35.916612       0   14.954422   16.842087
# 1094    24.477724       1   15.552854   14.578632
# 1095    24.477724       1   15.552854   14.578632
# 1096    16.747649       0   16.741771   14.997189
# 1097    10.968803       0   11.555881   14.918311
# 1098    31.106034       1   13.966274   15.727917
# 1099    31.106034       1   13.966274   15.727917
# 1100    16.532358       0   16.728539   14.908311
# 1101    16.739650       0   12.162862   14.931043
# 1102    16.965747       0   16.481907   16.651683
# 1103    16.965747       0   16.481907   16.651683
# 1104    28.531677       0   13.421640   17.161128
# 1105    28.531677       0   13.421640   17.161128
# 1106    28.677540       0   19.308752   15.534991
# 1107    28.677540       0   19.308752   15.534991
# 1108    28.677540       0   19.308752   15.534991
# 1109    28.677540       0   19.308752   15.534991
# 1110    28.677540       0   19.308752   15.534991
# 1111    10.490904       0   18.166852   15.787677
# 1112    16.025271       0   13.175579   14.491812
# 1113    38.342042       1   15.401973   17.231829
# 1114    38.342042       1   15.401973   17.231829
# 1115    38.342042       1   15.401973   17.231829
# 1116    38.342042       1   15.401973   17.231829
# 1117    38.342042       1   15.401973   17.231829
# 1118    38.342042       1   15.401973   17.231829
# 1119    27.322988       0   16.794142   22.405941
# 1120    27.322988       0   16.794142   22.405941
# 1121    14.602751       0   13.235149   15.467104
#
# [1122 rows x 11 columns]

# %%
df_win['result'] = 1
df_lose['result'] = 0

df_final = pd.concat((df_win,df_lose)).reset_index(drop=True)

df_final['AdjNetEff_Diff'] = df_final['AdjNetEff_x'] - df_final['AdjNetEff_y']

df_final = df_final[df_final['Season']<2015]

df_final = df_final.drop(['Season','WTeamID','LTeamID','AdjNetEff_x','AdjNetEff_y'],axis=1)
#df_final = df_final.drop(['Season','WTeamID','LTeamID'],axis=1)

df_final
# Out:
#       coty_x  off_cons_x  def_cons_x  coty_y  off_cons_y  def_cons_y  result  \
# 0          0   16.642408   14.289006       0   14.155399   18.094586       1
# 1          0   13.211491   13.021743       0   17.182535   13.232777       1
# 2          0   13.211491   13.021743       0   13.140022   16.089789       1
# 3          0   13.211491   13.021743       0   13.962640   19.286616       1
# 4          0   16.289954   17.096088       0    9.061950   14.344667       1
# 5          0   16.061633   12.116463       0   14.467639   15.065417       1
# 6          0   10.462607   15.701468       0   15.369050   15.957973       1
# 7          1   15.141179   12.875165       0   14.503437   15.874542       1
# 8          1   15.141179   12.875165       0   11.922719   12.970978       1
# 9          0   11.334966   16.073131       0   13.839161   15.873602       1
# 10         0   11.334966   16.073131       0   16.061633   12.116463       1
# 11         0   13.140022   16.089789       0   14.715984   16.387538       1
# 12         0   14.595200   15.069917       0   12.571454   17.449202       1
# 13         1   15.559062   15.839781       0   14.108326   11.457323       1
# 14         1   15.559062   15.839781       0   16.289954   17.096088       1
# 15         1   15.559062   15.839781       0   11.334966   16.073131       1
# 16         1   15.559062   15.839781       0   13.211491   13.021743       1
# 17         1   15.559062   15.839781       0   12.547894   11.749139       1
# 18         0   12.547894   11.749139       0   14.914222   17.632414       1
# 19         0   12.547894   11.749139       0   13.911666   15.913744       1
# 20         0   12.547894   11.749139       1   11.733838   13.815227       1
# 21         0   12.547894   11.749139       0   12.838221   13.238098       1
# 22         0   13.911666   15.913744       0   13.108164   11.619150       1
# 23         0   13.962640   19.286616       0   11.896788   16.996648       1
# 24         0   13.962640   19.286616       0   14.595200   15.069917       1
# 25         1   16.914175   13.776264       0   14.762176   13.299781       1
# 26         1   16.914175   13.776264       0   10.462607   15.701468       1
# 27         1   16.914175   13.776264       0   13.349464   16.105076       1
# 28         0   11.922719   12.970978       0   13.542722   14.666794       1
# 29         0   10.136824   14.423715       0   10.359828   14.674485       1
# ...      ...         ...         ...     ...         ...         ...     ...
# 1876       0   15.552308   17.968842       0   15.915161   16.258338       0
# 1877       0   14.354273   14.162396       0   15.915161   16.258338       0
# 1878       0   16.017140   15.342852       0   15.915161   16.258338       0
# 1879       0   15.182692   14.025538       0   15.915161   16.258338       0
# 1880       0   13.098350   12.971441       0   15.182692   14.025538       0
# 1881       0   14.393209   15.541365       0   15.182692   14.025538       0
# 1882       0   13.658817   17.736821       0   15.182692   14.025538       0
# 1883       0   14.018807   16.775219       0   16.017140   15.342852       0
# 1884       0   17.222558   15.544300       0   16.017140   15.342852       0
# 1885       0   12.646753   14.795933       0   17.222558   15.544300       0
# 1886       0   13.312260   16.382050       0   14.393209   15.541365       0
# 1887       0   14.172076   16.430572       0   12.925097   14.459476       0
# 1888       1   14.501510   14.066177       0   12.925097   14.459476       0
# 1889       0   15.460906   11.581596       1   15.329583   13.037132       0
# 1890       1   12.583098   19.884661       0   13.284274   14.373762       0
# 1891       0   12.428853   13.715628       0   13.284274   14.373762       0
# 1892       0   16.137926   16.213557       0   13.284274   14.373762       0
# 1893       0   16.597034   16.797523       0   13.284274   14.373762       0
# 1894       0   15.915161   16.258338       0   13.284274   14.373762       0
# 1895       0   15.108184   14.553682       0   12.820073   15.369256       0
# 1896       0   16.276069   18.218671       0   15.863647   17.700750       0
# 1897       0   15.729570   16.628929       1   14.501510   14.066177       0
# 1898       0   12.915781   11.865807       0   15.638496   15.002517       0
# 1899       0   13.576393   13.826803       0   13.852273   16.274999       0
# 1900       1   15.329583   13.037132       0   13.852273   16.274999       0
# 1901       0   16.885532   16.722436       0   16.353543   12.389822       0
# 1902       0   15.638496   15.002517       0   16.353543   12.389822       0
# 1903       1   14.309801   11.831578       1   15.148473   18.436961       0
# 1904       0   12.820073   15.369256       1   15.148473   18.436961       0
# 1905       0   13.259985   16.605070       0   12.428853   13.715628       0
#
#       AdjNetEff_Diff
# 0          -6.491479
# 1          25.295647
# 2          11.803546
# 3           6.483768
# 4           1.013994
# 5         -11.255168
# 6           0.215371
# 7          -1.433052
# 8           3.181876
# 9          17.349056
# 10         12.713879
# 11         -0.075305
# 12         14.985292
# 13         22.956920
# 14         12.174859
# 15          7.506530
# 16          2.687364
# 17          8.425322
# 18          9.661339
# 19          3.467522
# 20         -5.991943
# 21         -7.702243
# 22          6.495538
# 23          8.370977
# 24         -5.300329
# 25         33.699448
# 26         11.988344
# 27          9.110246
# 28          7.399368
# 29         -3.401130
# ...              ...
# 1876      -20.048948
# 1877       -6.179429
# 1878       -6.409206
# 1879        7.853627
# 1880      -34.066155
# 1881      -11.710549
# 1882      -12.656760
# 1883       -6.530045
# 1884        7.217013
# 1885      -21.329996
# 1886        3.070554
# 1887      -14.033707
# 1888       -4.722260
# 1889      -25.530754
# 1890       -7.367675
# 1891        2.272344
# 1892       11.638800
# 1893        2.800486
# 1894        2.824053
# 1895       -1.481135
# 1896       17.967254
# 1897       -4.092370
# 1898        9.953199
# 1899        1.097938
# 1900       10.923517
# 1901      -13.838712
# 1902      -12.849672
# 1903      -33.398561
# 1904      -10.572626
# 1905      -26.317742
#
# [1568 rows x 8 columns]

# %%
X = df_final.drop('result',axis=1)
y = df_final.result
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=1)

# %%
def best_model(model):
    print(model.best_score_)
    print(model.best_params_)
    print(model.best_estimator_)
def get_auc_scores(y_actual, method, method2):
    auc_score = roc_auc_score(y_actual, method)
    fpr_df, tpr_df, _ = roc_curve(y_actual, method2)
    return (auc_score, fpr_df, tpr_df)

# %%
param_grid = {'max_depth':[8],'gamma':np.logspace(start=-5,stop=3,num=9),
              'min_child_weight':[5],'learning_rate':[0.1],'n_estimators':[50]}
xgb_grid = GridSearchCV(XGBClassifier(),param_grid, cv=10, refit=True, verbose=0, scoring='neg_log_loss')
xgb_grid.fit(X_train, y_train)
best_model(xgb_grid)
# Out:
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [03:24:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# -0.5539498443179058
# {'gamma': 10.0, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'n_estimators': 50}
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=10.0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=8,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=50, n_jobs=8, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=True,
#               validate_parameters=1, verbosity=None)

# %%
param_grid = {'max_depth':[3,4,5,6,7],'max_features':[3,4,6],'n_estimators':[100,200,500]}
RanFor_grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=10, refit=True, verbose=0, scoring='neg_log_loss')
RanFor_grid.fit(X_train, y_train)
best_model(RanFor_grid)
# Out:
# -0.5452737692161049
# {'max_depth': 4, 'max_features': 6, 'n_estimators': 500}
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=6, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
param_grid = {'n_estimators':[50,100],
                'learning_rate':[0.1,0.2,0.3],
                'max_depth':[2,3,4],
                'min_samples_split':[5,10,15],
                'min_weight_fraction_leaf':[0.001,0.01,0.005],
                'subsample':[0.5,1],
                'max_features':['log2']}
SGB_Grid = GridSearchCV(GradientBoostingClassifier(),param_grid, cv=10, refit=True, verbose=0, scoring='neg_log_loss')
SGB_Grid.fit(X_train, y_train)
best_model(SGB_Grid)
# Out:
# -0.5466597191835789
# {'learning_rate': 0.2, 'max_depth': 2, 'max_features': 'log2', 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.001, 'n_estimators': 50, 'subsample': 1}
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.2, loss='deviance', max_depth=2,
#                            max_features='log2', max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=10,
#                            min_weight_fraction_leaf=0.001, n_estimators=50,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
param_grid = {'criterion':['entropy'],
              'splitter':['random'],
              'max_depth':[3,4,5,6],
              'min_samples_split':[2,3],
              'max_features':['log2']
}
DT_Grid = GridSearchCV(DecisionTreeClassifier(),param_grid, cv=10, refit=True, verbose=0, scoring='neg_log_loss')
DT_Grid.fit(X_train, y_train)
best_model(DT_Grid)
# Out:
# -0.6854859639360947
# {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 2, 'splitter': 'random'}
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#                        max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='random')

# %%
param_grid = {'n_estimators':[100],
              'algorithm':['SAMME'],
              'learning_rate':[0.5]
}
Ada_Grid = GridSearchCV(AdaBoostClassifier(),param_grid, cv=10, refit=True, verbose=0, scoring='neg_log_loss')
Ada_Grid.fit(X_train,y_train)
best_model(Ada_Grid)
# Out:
# -0.6547336209117264
# {'algorithm': 'SAMME', 'learning_rate': 0.5, 'n_estimators': 100}
# AdaBoostClassifier(algorithm='SAMME', base_estimator=None, learning_rate=0.5,
#                    n_estimators=100, random_state=None)

# %%
param_grid = {'C':np.logspace(start=-5,stop=3,num=9),
            'solver':['lbfgs','liblinear','sag','saga'],
            'max_iter':[50,100,200]
}
LogReg_Grid = GridSearchCV(LogisticRegression(),param_grid, cv=10, refit=True, verbose=0, scoring='neg_log_loss')
LogReg_Grid.fit(X_train, y_train)
best_model(LogReg_Grid)
# Out:
# -0.5409641861309087
# {'C': 0.001, 'max_iter': 50, 'solver': 'liblinear'}
# LogisticRegression(C=0.001, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=50,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
param_grid ={'alpha':np.logspace(start=-5,stop=3,num=9),
             'max_iter':[100,500,1000],
             'loss':['log','modified_huber']
}
SGD_Grid = GridSearchCV(SGDClassifier(),param_grid, cv=10,refit=True, verbose=0, scoring='neg_log_loss')
SGD_Grid.fit(X_train,y_train)
best_model(SGD_Grid)
# Out:
# -0.5417993505374588
# {'alpha': 1.0, 'loss': 'log', 'max_iter': 500}
# SGDClassifier(alpha=1.0, average=False, class_weight=None, early_stopping=False,
#               epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#               learning_rate='optimal', loss='log', max_iter=500,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
rf_model = RanFor_grid.best_estimator_
SGB_model = SGB_Grid.best_estimator_
xgb_model = xgb_grid.best_estimator_
DT_model = DT_Grid.best_estimator_
ada_model = Ada_Grid.best_estimator_
LR_model = LogReg_Grid.best_estimator_
SGD_model = SGD_Grid.best_estimator_

auc_XGB, fpr_XGB, tpr_XGB = get_auc_scores(y_test, xgb_model.predict(X_test),xgb_model.predict_proba(X_test)[:,1])
auc_RF, fpr_RF, tpr_RF = get_auc_scores(y_test, rf_model.predict(X_test),rf_model.predict_proba(X_test)[:,1])
auc_DT, fpr_DT, tpr_DT = get_auc_scores(y_test, DT_model.predict(X_test),DT_model.predict_proba(X_test)[:,1])
auc_SGB, fpr_SGB, tpr_SGB = get_auc_scores(y_test, SGB_model.predict(X_test),SGB_model.predict_proba(X_test)[:,1])
auc_ada, fpr_ada, tpr_ada = get_auc_scores(y_test, ada_model.predict(X_test),ada_model.predict_proba(X_test)[:,1])
auc_LR, fpr_LR, tpr_LR = get_auc_scores(y_test, LR_model.predict(X_test),LR_model.predict_proba(X_test)[:,1])
auc_SGD, fpr_SGD, tpr_SGD = get_auc_scores(y_test, SGD_model.predict(X_test),SGD_model.predict_proba(X_test)[:,1])

# %%
fig = plt.figure(figsize=(12,6), linewidth=1)
plt.plot(fpr_XGB, tpr_XGB, label='XGB score: ' + str(round(auc_XGB,5)))
plt.plot(fpr_RF, tpr_RF, label='RF score: ' + str(round(auc_RF,5)))
plt.plot(fpr_DT, tpr_DT, label='DT score: ' + str(round(auc_DT,5)))
plt.plot(fpr_SGB, tpr_SGB, label='SGB score: ' + str(round(auc_SGB,5)))
plt.plot(fpr_ada, tpr_ada, label='Ada score: ' + str(round(auc_ada,5)))
plt.plot(fpr_LR, tpr_LR, label='LogReg score: ' + str(round(auc_LR,5)))
plt.plot(fpr_SGD, tpr_SGD, label='SGD score: ' + str(round(auc_SGD,5)))
plt.plot([0,1],[0,1],'k--', label='Random: 0.5')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='best')

plt.show()

# %%
from sklearn.calibration import calibration_curve

# %%
plt.figure(figsize=(10, 10))
ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
ax2 = plt.subplot2grid((3, 1), (2, 0))

ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
for clf, name in [(LR_model, 'Logistic'),
                  (xgb_model, 'XGBoost'),
                  (SGD_model, 'SGD Classification'),
                  (rf_model, 'Random Forest')]:
    clf.fit(X_train, y_train)
    if hasattr(clf, "predict_proba"):
        prob_pos = clf.predict_proba(X_test)[:, 1]
    else:  # use decision function
        prob_pos = clf.decision_function(X_test)
        prob_pos = \
            (prob_pos - prob_pos.min()) / (prob_pos.max() - prob_pos.min())
    fraction_of_positives, mean_predicted_value = \
        calibration_curve(y_test, prob_pos, n_bins=10)

    ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
             label="%s" % (name, ))

    ax2.hist(prob_pos, range=(0, 1), bins=10, label=name,
             histtype="step", lw=2)

ax1.set_ylabel("Fraction of positives")
ax1.set_ylim([-0.05, 1.05])
ax1.legend(loc="lower right")
ax1.set_title('Calibration plots  (reliability curve)')

ax2.set_xlabel("Mean predicted value")
ax2.set_ylabel("Count")
ax2.legend(loc="upper center", ncol=2)

plt.tight_layout()
plt.show()
# Out:
# [03:32:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
min_features_to_select = 1 
lr_clf = LR_model
rfecv = RFECV(estimator=lr_clf, step=1, cv=10, scoring='neg_log_loss', min_features_to_select=min_features_to_select)
rfecv.fit(X_train,y_train)

print('Otpimal number of features: %d' % rfecv.n_features_)

plt.figure()
plt.xlabel('N of features selected')
plt.ylabel('Cross Validation score')
plt.plot(range(min_features_to_select,
               len(rfecv.grid_scores_) + min_features_to_select),
         rfecv.grid_scores_)
plt.show()
# Out:
# Otpimal number of features: 6

# %%
for i in range(X_train.shape[1]):
    print('Column %s, Selected %s, Rank %.3f' % (X_train.columns[i], rfecv.support_[i], rfecv.ranking_[i]))
# Out:
# Column coty_x, Selected False, Rank 2.000
# Column off_cons_x, Selected True, Rank 1.000
# Column def_cons_x, Selected True, Rank 1.000
# Column coty_y, Selected True, Rank 1.000
# Column off_cons_y, Selected True, Rank 1.000
# Column def_cons_y, Selected True, Rank 1.000
# Column AdjNetEff_Diff, Selected True, Rank 1.000

# %%
test_df = pd.read_csv('../input/kaggle_data/MSampleSubmissionStage1.csv')

# %%
test_df['Season'] = test_df['ID'].map(lambda x: int(x[:4]))
test_df['WTeamID'] = test_df['ID'].map(lambda x: int(x[5:9]))
test_df['LTeamID'] = test_df['ID'].map(lambda x: int(x[10:14]))
test_df
# Out:
#                    ID  Pred  Season  WTeamID  LTeamID
# 0      2015_1107_1112   0.5    2015     1107     1112
# 1      2015_1107_1116   0.5    2015     1107     1116
# 2      2015_1107_1124   0.5    2015     1107     1124
# 3      2015_1107_1125   0.5    2015     1107     1125
# 4      2015_1107_1129   0.5    2015     1107     1129
# 5      2015_1107_1138   0.5    2015     1107     1138
# 6      2015_1107_1139   0.5    2015     1107     1139
# 7      2015_1107_1140   0.5    2015     1107     1140
# 8      2015_1107_1153   0.5    2015     1107     1153
# 9      2015_1107_1157   0.5    2015     1107     1157
# 10     2015_1107_1172   0.5    2015     1107     1172
# 11     2015_1107_1173   0.5    2015     1107     1173
# 12     2015_1107_1181   0.5    2015     1107     1181
# 13     2015_1107_1186   0.5    2015     1107     1186
# 14     2015_1107_1207   0.5    2015     1107     1207
# 15     2015_1107_1208   0.5    2015     1107     1208
# 16     2015_1107_1209   0.5    2015     1107     1209
# 17     2015_1107_1211   0.5    2015     1107     1211
# 18     2015_1107_1214   0.5    2015     1107     1214
# 19     2015_1107_1217   0.5    2015     1107     1217
# 20     2015_1107_1231   0.5    2015     1107     1231
# 21     2015_1107_1234   0.5    2015     1107     1234
# 22     2015_1107_1235   0.5    2015     1107     1235
# 23     2015_1107_1242   0.5    2015     1107     1242
# 24     2015_1107_1246   0.5    2015     1107     1246
# 25     2015_1107_1248   0.5    2015     1107     1248
# 26     2015_1107_1257   0.5    2015     1107     1257
# 27     2015_1107_1261   0.5    2015     1107     1261
# 28     2015_1107_1264   0.5    2015     1107     1264
# 29     2015_1107_1268   0.5    2015     1107     1268
# ...               ...   ...     ...      ...      ...
# 11360  2019_1433_1459   0.5    2019     1433     1459
# 11361  2019_1433_1463   0.5    2019     1433     1463
# 11362  2019_1436_1437   0.5    2019     1436     1437
# 11363  2019_1436_1438   0.5    2019     1436     1438
# 11364  2019_1436_1439   0.5    2019     1436     1439
# 11365  2019_1436_1449   0.5    2019     1436     1449
# 11366  2019_1436_1458   0.5    2019     1436     1458
# 11367  2019_1436_1459   0.5    2019     1436     1459
# 11368  2019_1436_1463   0.5    2019     1436     1463
# 11369  2019_1437_1438   0.5    2019     1437     1438
# 11370  2019_1437_1439   0.5    2019     1437     1439
# 11371  2019_1437_1449   0.5    2019     1437     1449
# 11372  2019_1437_1458   0.5    2019     1437     1458
# 11373  2019_1437_1459   0.5    2019     1437     1459
# 11374  2019_1437_1463   0.5    2019     1437     1463
# 11375  2019_1438_1439   0.5    2019     1438     1439
# 11376  2019_1438_1449   0.5    2019     1438     1449
# 11377  2019_1438_1458   0.5    2019     1438     1458
# 11378  2019_1438_1459   0.5    2019     1438     1459
# 11379  2019_1438_1463   0.5    2019     1438     1463
# 11380  2019_1439_1449   0.5    2019     1439     1449
# 11381  2019_1439_1458   0.5    2019     1439     1458
# 11382  2019_1439_1459   0.5    2019     1439     1459
# 11383  2019_1439_1463   0.5    2019     1439     1463
# 11384  2019_1449_1458   0.5    2019     1449     1458
# 11385  2019_1449_1459   0.5    2019     1449     1459
# 11386  2019_1449_1463   0.5    2019     1449     1463
# 11387  2019_1458_1459   0.5    2019     1458     1459
# 11388  2019_1458_1463   0.5    2019     1458     1463
# 11389  2019_1459_1463   0.5    2019     1459     1463
#
# [11390 rows x 5 columns]

# %%
print(all_teams.columns)
# Out:
# Index(['Season', 'TeamID', 'AdjNetEff', 'coty', 'off_cons', 'def_cons'], dtype='object')

# %%
df = test_df.merge(all_teams, left_on=['Season','WTeamID'], right_on=['Season','TeamID'],how='left')
df.rename(columns={'AdjNet_Eff':'AdjNetEff_x','coyt':'coty_x','off_cons':'off_cons_x','def_cons':'def_cons_x'},inplace=True)
df = df.drop('TeamID',axis=1)
df = df.merge(all_teams, left_on=['Season','LTeamID'],right_on=['Season','TeamID'],how='left')
df.rename(columns={'AdjNet_Eff':'AdjNetEff_y','coyt':'coty_y','off_cons':'off_cons_y','def_cons':'def_cons_y'},inplace=True)
df['AdjNetEff_Diff'] = df['AdjNetEff_x'] - df['AdjNetEff_y']

df = df.drop(['TeamID','AdjNetEff_x','AdjNetEff_y','ID','Pred','Season','WTeamID','LTeamID'],axis=1)

df = df.drop_duplicates()

df
# Out:
#        coty_x  off_cons_x  def_cons_x  coty_y  off_cons_y  def_cons_y  \
# 0           0   16.213193   14.331449       0   12.686059   12.650090
# 1           0   16.213193   14.331449       0   12.225885   20.058701
# 2           0   16.213193   14.331449       0   15.242386   15.808386
# 3           0   16.213193   14.331449       0   16.700681   15.470556
# 4           0   16.213193   14.331449       0   15.796849   20.349861
# 5           0   16.213193   14.331449       0   13.316342   13.537010
# 6           0   16.213193   14.331449       0   16.713787   15.209442
# 7           0   16.213193   14.331449       0   12.803799   12.598343
# 8           0   16.213193   14.331449       0   17.266104   14.345523
# 9           0   16.213193   14.331449       1   14.068286   16.489205
# 10          0   16.213193   14.331449       0   17.397246   19.489200
# 11          0   16.213193   14.331449       0   14.776226   13.654375
# 12          0   16.213193   14.331449       0   17.647232   16.339465
# 13          0   16.213193   14.331449       0   14.239712   15.017116
# 14          0   16.213193   14.331449       0   14.684997   13.495087
# 15          0   16.213193   14.331449       0   13.217749   13.849146
# 16          0   16.213193   14.331449       0   16.892268   20.762103
# 17          0   16.213193   14.331449       0   15.454124   15.426512
# 18          0   16.213193   14.331449       0   13.369663   16.184122
# 19          0   16.213193   14.331449       0   19.791392   16.161377
# 20          0   16.213193   14.331449       0   14.985421   15.810849
# 21          0   16.213193   14.331449       0   13.494555   21.295475
# 22          0   16.213193   14.331449       0   12.200464   17.872923
# 23          0   16.213193   14.331449       1   16.761442   11.326935
# 24          0   16.213193   14.331449       0   12.625994   17.044066
# 25          0   16.213193   14.331449       0   18.462254   14.940903
# 26          0   16.213193   14.331449       0   14.518992   18.453309
# 27          0   16.213193   14.331449       0   11.015084   12.392211
# 28          0   16.213193   14.331449       0   12.425864   12.758025
# 29          0   16.213193   14.331449       0   11.844101   15.101250
# ...       ...         ...         ...     ...         ...         ...
# 11427       0   13.631023   14.105654       0   17.053913   16.477822
# 11428       0   13.631023   14.105654       0   18.070206   15.378596
# 11429       0   14.570757   16.014680       0   15.355736   14.555695
# 11430       0   14.570757   16.014680       1   15.401973   17.231829
# 11431       0   14.570757   16.014680       0   16.794142   22.405941
# 11432       0   14.570757   16.014680       0   13.235149   15.467104
# 11433       0   14.570757   16.014680       0   15.708520   12.612383
# 11434       0   14.570757   16.014680       0   17.053913   16.477822
# 11435       0   14.570757   16.014680       0   18.070206   15.378596
# 11436       0   15.355736   14.555695       1   15.401973   17.231829
# 11437       0   15.355736   14.555695       0   16.794142   22.405941
# 11438       0   15.355736   14.555695       0   13.235149   15.467104
# 11439       0   15.355736   14.555695       0   15.708520   12.612383
# 11440       0   15.355736   14.555695       0   17.053913   16.477822
# 11441       0   15.355736   14.555695       0   18.070206   15.378596
# 11442       1   15.401973   17.231829       0   16.794142   22.405941
# 11443       1   15.401973   17.231829       0   13.235149   15.467104
# 11444       1   15.401973   17.231829       0   15.708520   12.612383
# 11445       1   15.401973   17.231829       0   17.053913   16.477822
# 11446       1   15.401973   17.231829       0   18.070206   15.378596
# 11447       0   16.794142   22.405941       0   13.235149   15.467104
# 11448       0   16.794142   22.405941       0   15.708520   12.612383
# 11449       0   16.794142   22.405941       0   17.053913   16.477822
# 11450       0   16.794142   22.405941       0   18.070206   15.378596
# 11451       0   13.235149   15.467104       0   15.708520   12.612383
# 11452       0   13.235149   15.467104       0   17.053913   16.477822
# 11453       0   13.235149   15.467104       0   18.070206   15.378596
# 11454       0   15.708520   12.612383       0   17.053913   16.477822
# 11455       0   15.708520   12.612383       0   18.070206   15.378596
# 11456       0   17.053913   16.477822       0   18.070206   15.378596
#
#        AdjNetEff_Diff
# 0          -30.931605
# 1          -14.828868
# 2          -22.772427
# 3            1.271728
# 4          -13.015081
# 5          -10.272515
# 6          -19.078222
# 7          -16.316384
# 8          -12.161799
# 9            1.251034
# 10         -15.533121
# 11         -11.759863
# 12         -30.605468
# 13          -0.422338
# 14         -17.876082
# 15         -13.286490
# 16          -7.796153
# 17         -28.869941
# 18          13.143502
# 19          -5.316000
# 20         -12.995163
# 21         -17.025269
# 22         -21.830285
# 23         -22.454825
# 24         -38.633036
# 25           4.875734
# 26         -20.529168
# 27         -10.934978
# 28           2.669889
# 29         -14.631650
# ...               ...
# 11427       -4.668658
# 11428        7.722867
# 11429       -9.240547
# 11430      -28.111930
# 11431      -17.092876
# 11432       -4.372639
# 11433      -14.649335
# 11434      -11.561934
# 11435        0.829591
# 11436      -18.871383
# 11437       -7.852329
# 11438        4.867908
# 11439       -5.408788
# 11440       -2.321387
# 11441       10.070138
# 11442       11.019054
# 11443       23.739291
# 11444       13.462595
# 11445       16.549996
# 11446       28.941520
# 11447       12.720237
# 11448        2.443541
# 11449        5.530942
# 11450       17.922467
# 11451      -10.276696
# 11452       -7.189295
# 11453        5.202230
# 11454        3.087401
# 11455       15.478926
# 11456       12.391525
#
# [11390 rows x 7 columns]

# %%
test_pred = lr_clf.predict_proba(df)[:,1]
len(test_pred)
# Out:
# 11390

# %%
submission_df = pd.read_csv('../input/kaggle_data/MSampleSubmissionStage1.csv')
submission_df['Pred'] = test_pred
submission_df
len(submission_df)
# Out:
# 11390

# %%
submission_df['Pred'].hist()

# %%
submission_df.to_csv('../submissions/Square3.csv', index=False)
